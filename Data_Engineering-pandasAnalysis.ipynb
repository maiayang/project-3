# %%
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import json
from pprint import pprint
import sqlite3
import pandas as pd

# %%
chicken_recipe_df = pd.read_csv('Resources/chicken_recipe.csv')
co2_df = pd.read_csv('Resources/co2.csv')

# %%
# Display summary statistics for chicken_recipe_df
summary_statistics_chicken = chicken_recipe_df.describe()

# %%
# Calculate average CO2 emissions per recipe and merge with co2_df
avg_co2_per_recipe = co2_df.groupby('recipe_id')['total_co2'].mean().reset_index()
co2_df = co2_df.merge(avg_co2_per_recipe, on='recipe_id', how='left', suffixes=('_original', '_average'))

# Perform the scatter plot for CO2 data
plt.figure(figsize=(10, 6))
sns.scatterplot(x='number_of_ingredients', y='total_co2_average', data=co2_df)
plt.title('Correlation between Number of Ingredients and Total CO2')
plt.xlabel('Number of Ingredients')
plt.ylabel('Average Total CO2')
plt.show()

# %%
# Calculate average CO2 emissions per recipe
avg_co2_per_recipe = co2_df.groupby('recipe_id')['total_co2_original'].mean().reset_index()

# Display available recipes to the user
print("Available Recipes:")
for index, recipe in enumerate(chicken_recipe_df['recipe_name']):
    print(f"{index + 1}. {recipe}")

# Get user input for recipe selection
selected_recipe_index = int(input("\nEnter the number corresponding to the recipe you want to select: ")) - 1

# Check if the selected index is valid
if 0 <= selected_recipe_index < len(chicken_recipe_df):
    selected_recipe_id = chicken_recipe_df.iloc[selected_recipe_index]['recipe_id']

    # Get the corresponding average CO2 content
    avg_co2_content = avg_co2_per_recipe[avg_co2_per_recipe['recipe_id'] == selected_recipe_id]['total_co2_original'].values[0]

    # Display information
    selected_cuisine_type = chicken_recipe_df.iloc[selected_recipe_index]['cuisine_type']
    formatted_cuisine_type = ''.join(selected_cuisine_type).replace(' ', '')  # Remove spaces
    print(f"\nRecipe: {chicken_recipe_df.iloc[selected_recipe_index]['recipe_name']}")
    print(f"CO2 Content: {avg_co2_content} grams")
    print(f"Average Calories per Serving: {chicken_recipe_df.iloc[selected_recipe_index]['calories_per_serving']} calories")
    print(f"Total Time per Recipe: {chicken_recipe_df.iloc[selected_recipe_index]['total_time']} minutes")
    print(f"Cuisine Type: {formatted_cuisine_type}")
else:
    print("Invalid selection. Please choose a valid recipe.")
# Out:
# Available Recipes:
# 1. Poached Chicken for Tacos
# 2. Chicken Broth
# 3. Fig & Balsamic Chicken
# 4. Basic Roast Chicken
# 5. Ultimate Roast Chicken
# 6. Chicken & peppers
# 7. Chicken Tamales
# 8. Chicken biryani
# 9. Roast Chicken With Chicken Livers
# 10. Chicken Carbonara
# 11. Chicken Parmigiana recipes
# 12. Chicken Piccata
# 13. Chicken Tacos
# 14. Homemade Essence of Chicken
# 15. Chicken Fricassee
# 16. Lemon & Caper Chicken
# 17. Chicken Piccata
# 18. Chicken paprika
# 19. Chicken Liver Pâté
# 20. Chicken Kiev
# 21. Chicken Piccata
# 22. Quinoa-Crusted Chicken
# 23. Chicken Piccata Hilary
# 24. Braised Chicken Gumbo
# 25. Chicken Marengo
# 26. Chicken Pie
# 27. Firecracker Chicken
# 28. Chicken soup
# 29. Chicken Teriyaki
# 30. Chicken Potpies
# 31. Chicken & sweetcorn ramen
# 32. Barbecued Chicken
# 33. Chicken Piccata
# 34. Roast Chicken Breasts With Chicken Gravy
# 35. Lemon Chicken
# 36. Chicken Satay
# 37. Chicken Quinoa
# 38. Chicken Broth
# 39. Braised Chicken Sausages
# 40. Chicken Paillard
# 41. Crispy Chicken Dippers
# 42. Southwestern Chicken Soup
# 43. Chicken Risotto
# 44. Easy Chicken Posole
# 45. Chicken With Jerk Marinade
# 46. Easy Chicken Soup
# 47. Chicken Liver Paté
# 48. Stuffed Chicken Caprese
# 49. Chicken Tacos
# 50. Lemon Chicken
# 51. Chicken Roulades
# 52. Lemon Chicken
# 53. Peanut-Roasted Chicken
# 54. Un-Fried Chicken
# 55. Twistin’ Chicken
# 56. Pulled Chicken
# 57. Chicken Cacciatore
# 58. Chicken Satay
# 59. Chicken Francese
# 60. Chicken Carbonara
# 61. Delicate Chicken Soup
# 62. Greek Chicken
# 63. Chicken Mole
# 64. Quick Teriyaki Chicken
# 65. Champagne-Can Chicken
# 66. Lemon Chicken Soup
# 67. Chicken and Dumplings
# 68. Chicken Piccata
# 69. Chicken Roulade
# 70. Chicken Piccata
# 71. Chicken Gnocchi Soup
# 72. Chicken Piccata
# 73. Cornbread Chicken Bake
# 74. Circassian Chicken
# 75. Chicken Parmesan Dumplings
# 76. Pan-Fried Chicken
# 77. Chicken and mushrooms
# 78. Provencal Chicken
# 79. Meal-Prep Curried Chicken & Chili-Lime Chicken
# 80. Chicken Stock
# 81. Chicken Tinga
# 82. Kickin' Chicken
# 83. Chicken Saltimbocca
# 84. Chicken Saltimboca
# 85. Chicken Piccata
# 86. Chicken Souffle
# 87. Roast Chicken and Vegetable Soup
# 88. Chicken Marsala
# 89. Chicken Piccata
# 90. Chicken Marsala
# 91. Buttermilk Brined Chicken
# 92. Garlic Chicken
# 93. Drunken Chicken Recipe
# 94. Circassian Chicken
# 95. Chicken Marsala
# 96. Roast Chicken
# 97. Chicken Tacos
# 98. Chicken Piccata
# 99. Chicken Tetrazzini
# 100. Chicken Biryani
# 101. Sticky chicken
# 102. Lemon Pepper Chicken
# 103. Chicken Chili
# 104. Sticky barbecue chicken
# 105. Chicken Cacciatore
# 106. Chicken & chorizo traybake
# 107. Roast Chicken
# 108. Classic Chicken Soup
# 109. Fried Chicken
# 110. Chicken Saltimbocca
# 111. Chicken Tetrazzini Recipe
# 112. Marmalade Chicken
# 113. Chicken Piccata
# 114. Rosemary Fried Chicken recipes
# 115. Chicken Thighs Confit
# 116. Chicken ‘paella’
# 117. Citrus Chicken and Rice
# 118. Spinach Artichoke Chicken
# 119. Classic Baked Chicken
# 120. Chicken in Gravy
# 121. Chicken and Tortellini Stew
# 122. Chicken Francese
# 123. Chicken Marsala
# 124. Asian Grilled Chicken
# 125. Lemon Chicken
# 126. Chicken Scarpariello
# 127. Chicken Scarpariello
# 128. Chicken Marsala III
# 129. Roast Chicken
# 130. Balsamic Chicken
# 131. Cardamom Honey Chicken
# 132. Rosemary Chicken
# 133. Chicken "Stoup"
# 134. Chicken Cordon Bleu
# 135. Chicken Posole
# 136. Chicken pie
# 137. Apricot Glazed Chicken
# 138. Chicken Hotpot
# 139. Halfsies Chicken
# 140. Chicken Saltimbocca
# 141. Chicken Piccata
# 142. Chicken Marsala
# 143. Chicken Tortellini Soup
# 144. Chicken Couscous Salad
# 145. Chicken Mole
# 146. Chicken Mushroom Marsala
# 147. Mango Chicken With Couscous
# 148. Chicken Piccata
# 149. Chicken Fried Rice
# 150. Chicken Fingers
# 151. Belgian Chicken Waterzooi
# 152. Candy Chicken
# 153. Chicken Paillard
# 154. Chicken Tacos
# 155. Chicken and Peaches
# 156. Speedy Chicken Enchiladas
# 157. Pan-Fried Chicken
# 158. Teriyaki Chicken
# 159. Chicken Paprikash
# 160. Chicken Cacciatore
# 161. Spatchcocked Saffron Chicken
# 162. Roast Chicken
# 163. Chicken biryani
# 164. Spa Chicken
# 165. Grilled Chicken
# 166. Chicken with Grapefruit
# 167. Easy chicken pie
# 168. Nutmeg Chicken
# 169. Creamy Chicken & Leeks
# 170. Chicken Quesadillas
# 171. Chicken Lo Mein
# 172. Tuscan Chicken
# 173. Hearty Chicken Noodle Soup
# 174. Chicken Scallopine recipes
# 175. Chicken Paprikash
# 176. Caramel Chicken
# 177. Summer Traybake Chicken
# 178. Chicken Marsala
# 179. Mustard Chicken
# 180. Roasted Lemon Chicken With Pistachios
# 181. Sticky Lemon Chicken
# 182. Mexican Chicken
# 183. Chicken and Dumplings
# 184. Chicken Paprikash
# 185. Shredded Chicken Gorditas
# 186. Chicken Galliano
# 187. Chicken Marsala
# 188. Barbecue Chicken
# 189. Chicken Forestiere
# 190. Thai Chicken Salad
# 191. Chicken Saltimbocca
# 192. Sesame Chicken
# 193. Fried Chicken
# 194. Chicken Scallopine
# 195. Greek Lemon Chicken Soup
# 196. The Smith's Chicken-Fried Chicken Skins
# 197. Saucy chicken & vegetables
# 198. Chicken Tortilla Soup
# 199. Chicken and Tortellini Soup
# 200. Skillet Chicken and Rice
#
# Recipe: Poached Chicken for Tacos
# CO2 Content: 4026.96 grams
# Average Calories per Serving: 216.24 calories
# Total Time per Recipe: 120.0 minutes
# Cuisine Type: ['mexican']
